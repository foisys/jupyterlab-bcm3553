# %%
# !pip install --upgrade matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 1.8 MB/s  0:00:04 eta 0:00:01
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.2
#     Uninstalling matplotlib-3.8.2:
#       Successfully uninstalled matplotlib-3.8.2
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot

counts = pd.read_csv("../z.misc_files/data_tab/t47d_bisphenol_counts.csv")
counts.set_index("EnsemblID", inplace=True)

counts_corr = counts + 5
print(counts_corr)

#plot.hist(counts["t47d_dmso_r1.bam"])
# Out:
#                    t47d_dmso_r1.bam  t47d_dmso_r2.bam  t47d_estradiol_r1.bam  \
# EnsemblID
# ENSG00000290825.1                 5                 5                      5
# ENSG00000223972.6                 5                 5                      5
# ENSG00000227232.5               114                92                    110
# ENSG00000278267.1                 5                 5                      5
# ENSG00000243485.5                 5                 5                      6
# ...                             ...               ...                    ...
# ENSG00000198695.2             29545             28443                  15950
# ENSG00000210194.1                24                25                     36
# ENSG00000198727.2            158313            123250                  72095
# ENSG00000210195.2                35                28                     59
# ENSG00000210196.2               347               260                    300
#
# ...
