# %% [markdown]
# # Comment faire une représentation graphique des annotations d'une séquence
#
# ## Introduction
#
# Ok, on voit qu'il va falloir travailler un peu plus fort pour obtenir un résultat plus convaincant, plus informatif :-) On va associer BioPython à la librairie [DNA Feature Viewer](https://github.com/Edinburgh-Genome-Foundry/DnaFeaturesViewer) (avec une documentation complémentaire [ici](https://edinburgh-genome-foundry.github.io/DnaFeaturesViewer/index.html) pour mieux réussir notre dessin.

# %%
# Si ce n'est pas déjà fait, installons la librairie
# avec mise à jour si une version plus récente existe...
! pip install --upgrade dna_features_viewer

# %%
# Importons la librairie DNA Features Viewer, capable de 
# lire les fichiers via BioPython
from Bio import SeqIO
from dna_features_viewer import BiopythonTranslator

for record in SeqIO.parse("../z.misc_files/data_seq/vector.pGEM-9Zf-minus.gb","gb"):
#    print(record.features)
    for aFeature in record.features:
        print(aFeature)

# C'est un début...
#dnaGraphics = BiopythonTranslator().translate_record("../z.misc_files/data_seq/vector.pGEM-9Zf-minus.gb")
#ax, _ = dnaGraphics.plot(strand_in_label_threshold=10)
