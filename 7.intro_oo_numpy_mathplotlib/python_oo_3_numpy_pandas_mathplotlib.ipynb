# %% [markdown]
# # Python pour biochimistes: programmation orientée-objet et création de graphes
#
# ## Introduction
#
#
#
# ## Pré-requis
#
# Il faut s'assurer d'avoir les modules nécessaires dans notre environnement:

# %%
# !pip install numpy pandas matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/bioubuntu/.local/lib/python3.10/site-packages (1.26.3)
# Requirement already satisfied: pandas in /home/bioubuntu/.local/lib/python3.10/site-packages (2.1.4)
# Requirement already satisfied: matplotlib in /home/bioubuntu/.local/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/bioubuntu/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/bioubuntu/.local/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: cycler>=0.10 in /home/bioubuntu/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in /home/bioubuntu/.local/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bioubuntu/.local/lib/python3.10/site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/bioubuntu/.local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/bioubuntu/.local/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/bioubuntu/.local/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
