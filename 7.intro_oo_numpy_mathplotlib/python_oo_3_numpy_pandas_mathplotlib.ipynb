# %% [markdown]
# <h1 id="Python-pour-biochimistes:-une-introduction-&agrave;-la-notion-de-la-programmation-orient&eacute;-objet">Python pour biochimistes: programmation orient&eacute;e-objet et cr&eacute;ation de graphes</h1>
# <h2 id="Introduction">Introduction</h2>
# <p>&nbsp;</p>
# <h2>Pr&eacute;-requis</h2>
# <p>Il faut s'assurer d'avoir les modules n&eacute;cessaires dans notre environnement:</p>

# %%
# !pip install numpy pandas matplotlib
