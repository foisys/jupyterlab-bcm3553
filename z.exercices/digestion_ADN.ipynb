# %% [markdown]
# <h1>Petit exercice: mettons les morceaux ensemble!</h1>
# <p>Ok, on en sait suffisamment en Python pour tenter notre coup... Comment cr&eacute;er un script qui nous dira quel enzyme de restriction, provenant d'une liste donn&eacute;e, est capable de couper une s&eacute;quence d'ADN&nbsp;</p>
