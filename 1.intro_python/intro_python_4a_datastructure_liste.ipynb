# %% [markdown]
# <h1 id="Python-pour-biochimistes:-un-langage-de-programmation-abordable-pour-tous">Python pour biochimistes: les structures de donn&eacute;es</h1>
# <h2 id="&Eacute;crire-votre-code">Structures de donn&eacute;es: stocker vos informations de mani&egrave;re accessible</h2>
# <p>Donc, c'est facile de cr&eacute;er des variables :-) La plupart du temps cependant, nous voulons aller plus loin; par exemple, comment repr&eacute;senter des infos sur une personne ou un objet ou bien repr&eacute;senter un ensemble de variables similaires (ou pas!). On se doit d'utiliser des variables un peu sp&eacute;ciales appel&eacute;es <em>structures de donn&eacute;es</em>. Tous les languages de programmation poss&egrave;dent des fa&ccedil;ons de cr&eacute;er ces structures de donn&eacute;es et Python n'est pas exception. Voici les types les plus courants de structures de donn&eacute;es:</p>
# <ul>
# <li>Les listes;</li>
# <li>Les <em>tuples</em>;</li>
# <li>Les <em>sets</em> ou ensembles;</li>
# <li>Les dictionnaires.</li>
# </ul>

# %% [markdown]
# <h2 id="Utilisations-des-listes">Utilisations des listes</h2>
# <p>Une liste est un type de variable qui contient plusieurs autres variables (duh!). Une liste &agrave; certaines propri&eacute;t&eacute;s:</p>
# <ul>
# <li>Une liste peut contenir n'importe quoi sans que ce soit des variables de m&ecirc;me type. Par ex.: une liste peut contenir une autre liste.</li>
# <li>Les items de la liste sont toujours ordonn&eacute;s en ordre de cr&eacute;ation via un processus d'indexation o~u le premier item &agrave; toujours l'index 0 (z&eacute;ro).</li>
# <li>Les items d'une liste sont modifiables: on peut en retirer ou en ins&eacute;rer tout autant qu'on peut modifier le contenu d'un des items de la liste.</li>
# <li>Une liste peut contenir des doublons.</li>
# </ul>
# <h3 id="Comment-travailler-avec-des-listes?">Comment cr&eacute;er des listes?</h3>

# %%
# On peut créer des listes de deux manières différentes

# Primo de manière explicite avec les crochets
uneListe1 = ["yoda","luke","indy","salah"]
print(uneListe1)

# Secundo, en créant une liste vide via un constructeur
# qui sera remplie programmatiquement
uneListe2 = list()
for i in range(5):
    # Remarquez la fonction append qui s'applique à une liste
    uneListe2.append(i)
print(uneListe2)
# Out:
# ['yoda', 'luke', 'indy', 'salah']
# [0, 1, 2, 3, 4]

# %% [markdown]
# <h3>Comment acc&eacute;der au contenu d'une liste?</h3>
# <p>Il y adiff&eacute;rentes fa&ccedil;ons d'obtenir les &eacute;l&eacute;ments d'une liste:</p>
# <ul>
# <li>En sp&eacute;cifiant l'index d'un objet ou un intervalle d'index</li>
# <li>En utilisant l'it&eacute;rateur implicitement cr&eacute;&eacute; lorsque la liste &agrave; &eacute;t&eacute; cr&eacute;&eacute;e&nbsp;</li>
# </ul>

# %%
# Spécifions un index
print(uneListe1[2])

# Spécifions un intervalle
# qui est une autre liste :-)
print(uneListe1[0:2])

# Utilison l'itérateur qui parcourera
# la liste du début jusqu'à la fin
for i in uneListe1:
    print(i)
# Out:
# indy
# ['yoda', 'luke']
# yoda
# luke
# indy
# salah

# %% [markdown]
# <h3>Comment changer (addition / d&eacute;l&eacute;tion) le contenu d'une liste?</h3>
# <p>Tr&egrave;s simplement!&nbsp;</p>
# <ul>
# <li>En changeant sp&eacute;cifiquement un item via son index;</li>
# <li>En ins&eacute;rant ou ajoutant un &eacute;l&eacute;ment via diverses fonctions de liste.</li>
# </ul>

# %%
# Changeons yoda pour ben kenobi
uneListe1[0] = "ben kenobi"
print(uneListe1)
# Out:
# ['ben kenobi', 'luke', 'indy', 'salah']

# %%
# iInsérons maintenant leia entre luke et indy
uneListe1.insert(2,"leia")
print(uneListe1)
# Out:
# ['ben kenobi', 'luke', 'leaia', 'indy', 'salah']

# %%
# Ajoutons deux items à cette liste
# avec append(). Ils seront insérés à la fin 
uneListe1.append("vader")
uneListe1.append("maul")
print(uneListe1)
# Out:
# ['ben kenobi', 'luke', 'leaia', 'indy', 'salah', 'vader', 'maul']

# %%
# Pour enlever un item de la liste, deux
# façons

# Spécifiquement si on le connais avec remove()
uneListe1.remove("vader")

# Ou bien via son index avec pop()
uneListe1.pop(0)

print(uneListe1)
# Out:
# ['luke', 'leaia', 'indy', 'salah', 'maul']

# %% [markdown]
# <h3 id="Comment-changer-(addition-/-d&eacute;l&eacute;tion)-le-contenu-d'une-liste?">Comment cloner/copier des listes?</h3>
# <p>Encore tr&egrave;s simplement!&nbsp;</p>

# %%
# Imaginoins que nous voulons cloner uneListe2...
uneListe3 = uneListe2

# Retirons le ernier élément de uneListe2
uneListe2.pop()

print(uneListe2)
print(uneListe3)
# Out:
# [0, 1, 2, 3]
# [0, 1, 2, 3]

# %%
# Remarquez que uneListe3 n'est pas identique à uneListe2 AVANT la commande pop()
# Remettons la dernière valeur
uneListe2.insert(4,4)
# On fait la copie
uneListe3 = uneListe2.copy()
# On retire la derniere valeur
uneListe2.pop()
# On vérifie le résultat
print(uneListe2)
# uneListe3 est vraiment une copie intacte
print(uneListe3)
# Out:
# [0, 1, 2, 3]
# [0, 1, 2, 3, 4]

# %%
# Pour fusionner deux listes

# Simplement par concaténation
uneListe4 = uneListe1+uneListe2

# avec la méthode extend()
uneListe1.extend(uneListe3)

print(uneListe4)
# Allongée du contenu de uneListe3
print(uneListe1)
# Out:
# ['luke', 'leaia', 'indy', 'salah', 'maul', 0, 1, 2, 3]
# ['luke', 'leaia', 'indy', 'salah', 'maul', 0, 1, 2, 3, 4]
