# %% [markdown]
# <h1 id="Python-pour-biochimistes:-un-langage-de-programmation-abordable-pour-tous">Python pour biochimistes: un langage de programmation abordable pour tous</h1>
# <h2>&Eacute;crire votre code</h2>
# <p>&Eacute;videmment, un script contiendra plusieurs items, r&eacute;parti sur plusieurs lignes. Comment Python interpr&egrave;te vos instructions? Dans une majorit&eacute; de languages, les blocs d'instructions sont s&eacute;par&eacute;s par des caract&egrave;res sp&eacute;ciaux, tel que les acoclades ('{' ou '}'). Python fonctionne diff&eacute;remment: on utilisera plut&ocirc;t des indentations, c'est-&agrave;-dire des espaces qui s&eacute;parerons les blocs.</p>
# <p>Note: l'indentation par d&eacute;faut de Jupyter est de 4 espaces.</p>
# <p>Un exemple:&nbsp;</p>

# %%
#
# La fonction range() permet de créer une itération entre 0 et 5
# dans notre cas
#
for i in range(6):
    # Remarquez que j'ai doit forcer i et j à devenir une chaine de caractères
    # pour que la concaténation fonctionne
    print("Boucle "+ str(i))
    j = i+10
    print("Valeur: "+str(j))
# Out:
# Boucle 0
# Valeur: 10
# Boucle 1
# Valeur: 11
# Boucle 2
# Valeur: 12
# Boucle 3
# Valeur: 13
# Boucle 4
# Valeur: 14
# Boucle 5
# Valeur: 15

# %% [markdown]
# <p>Que se passe-t-il si on n'a pas la bonne indentation?</p>
# <p>Exemple:</p>

# %%
for i in range(6):
    # Remarquez que j'ai doit forcer i et j à devenir une chaine de caractères
    # pour que la concaténation fonctionne
    print("Boucle "+ str(i))
    j = i+10
        print("Valeur: "+str(j))
# Out:
#   Cell In[17], line 6
#     print("Valeur: "+str(j))
#     ^
# IndentationError: unexpected indent
