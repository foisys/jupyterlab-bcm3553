# %% [markdown]
# <h1 id="Pr&eacute;paration-de-l'environnement-de-d&eacute;veloppement">Pr&eacute;paration de l'environnement de d&eacute;veloppement</h1>
# <h2 id="Introduction">Introduction</h2>
# <p>Pour r&eacute;soudre notre probl&egrave;me, on a besoin d'un outil: un language de programmation. Ce language doit nous permettre de communiquer avec le mat&eacute;riel de l'ordinateur afin d'ex&eacute;cuter les t&acirc;ches n&eacute;cessaires pour accomplir nos t&acirc;ches: lecture et &eacute;criture sur le syst&egrave;me de fichier, traitement de l'information, connexions avec le monde ext&eacute;rieur si n&eacute;cessaire.</p>
# <h2 id="Nos-outils">Nos outils</h2>
# <p>Comment &nbsp;utiliser un language? La mani&egrave;re la plus simple se fait via un simple fichier en format texte, &eacute;crit via un &eacute;diteur de texte. Simple mais limit&eacute;... Une approche plus payante est l'utilisation d'un environnement de d&eacute;veloppement int&eacute;gr&eacute;. Duh? C'est un logiciel offrant des fonctionnalit&eacute;s compl&eacute;mentaires comme l'indentation automatique ou l'autocorrection. Il existe une multitude de ces outils mais un d'entre eux qui est tr&egrave;s populaire est <a href="http://jupyter.org" target="_blank" rel="noopener">Jupyter</a>. &nbsp;Pourquoi? Parce qu'en plus d'&eacute;crire du code, il est facile de compl&eacute;ter ce code avec de la documentation dans la m&ecirc;me plateforme.</p>
# <h2 id="Installation">Installation</h2>
# <p>Donc comment faire avec Jupyter?</p>
# <ol>
# <li>Premi&egrave;rement, il fait avoir Python 3 install&eacute; sur votre ordinateur. Sur une Mac ou sur un poste Linux/Unix, c'est d&eacute;j&agrave; fait ;-) Sur Windows, il faut installer le package provenant du site de Python: <a title="Page des installateurs Windows 7 et plus" href="https://www.python.org/downloads/windows/" target="_blank" rel="noopener">Page des installateurs Windows 7 et plus.</a></li>
# <li>Il est tr&egrave;s facile alors d'insteller Jupyter Lab:</li>
# </ol>
# <p><code>% pip3 install jupyterlab</code><br /><br />On d&eacute;marre alors notre environement ainsi:</p>
# <p><code>% mkdir mon_projet</code><br /><code>% jupyter lab --notebook-dir= ./mon_projet</code></p>
# <p>Une&nbsp;<code></code></p>

# %%
# !pip3 install jupyterlab
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyterlab in /Users/foisys/Library/Python/3.9/lib/python/site-packages (3.6.6)
# Requirement already satisfied: ipython in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (8.12.0)
# Requirement already satisfied: packaging in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (23.0)
# Requirement already satisfied: tornado>=6.1.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (6.3.1)
# Requirement already satisfied: jupyter-core in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (5.3.0)
# Requirement already satisfied: jupyterlab-server~=2.19 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (2.22.1)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (2.5.0)
# Requirement already satisfied: jupyter-ydoc~=0.2.4 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: jupyter-server-ydoc~=0.8.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (0.8.0)
# Requirement already satisfied: nbclassic in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (0.5.5)
# Requirement already satisfied: notebook<7 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (6.5.4)
# Requirement already satisfied: jinja2>=2.1 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (3.1.2)
# Requirement already satisfied: tomli in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jinja2>=2.1->jupyterlab) (2.1.2)
# Requirement already satisfied: anyio>=3.1.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (3.6.2)
# Requirement already satisfied: argon2-cffi in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (8.2.0)
# Requirement already satisfied: jupyter-events>=0.4.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (7.3.1)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.8.0)
# Requirement already satisfied: prometheus-client in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.16.0)
# Requirement already satisfied: pyzmq>=24 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (25.0.2)
# Requirement already satisfied: send2trash in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.9.0)
# Requirement already satisfied: websocket-client in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-core->jupyterlab) (3.4.0)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab) (0.9.0)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-server-ydoc~=0.8.0->jupyterlab) (0.8.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-ydoc~=0.2.4->jupyterlab) (6.0.0)
# Requirement already satisfied: y-py<0.6.0,>=0.5.3 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-ydoc~=0.2.4->jupyterlab) (0.5.9)
# Requirement already satisfied: babel>=2.10 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server~=2.19->jupyterlab) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server~=2.19->jupyterlab) (0.9.11)
# Requirement already satisfied: jsonschema>=4.17.3 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server~=2.19->jupyterlab) (4.17.3)
# Requirement already satisfied: requests>=2.28 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyterlab-server~=2.19->jupyterlab) (2.28.2)
# Requirement already satisfied: ipython-genutils in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from notebook<7->jupyterlab) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from notebook<7->jupyterlab) (1.5.6)
# Requirement already satisfied: ipykernel in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from notebook<7->jupyterlab) (6.22.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbclassic->jupyterlab) (0.2.3)
# Requirement already satisfied: backcall in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: decorator in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (2.14.0)
# Requirement already satisfied: stack-data in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (0.6.2)
# Requirement already satisfied: typing-extensions in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (4.5.0)
# Requirement already satisfied: pexpect>4.3 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (4.8.0)
# Requirement already satisfied: appnope in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipython->jupyterlab) (0.1.3)
# Requirement already satisfied: idna>=2.8 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6->jupyter-ydoc~=0.2.4->jupyterlab) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (0.19.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.8.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.4.0->jupyter-server<3,>=1.16.0->jupyterlab) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.4.0->jupyter-server<3,>=1.16.0->jupyterlab) (6.0)
# Requirement already satisfied: rfc3339-validator in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.4.0->jupyter-server<3,>=1.16.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.4.0->jupyter-server<3,>=1.16.0->jupyterlab) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.12.2)
# Requirement already satisfied: bleach in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (6.0.0)
# Requirement already satisfied: defusedxml in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.2.1)
# Requirement already satisfied: fastjsonschema in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.16.0->jupyterlab) (2.16.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython->jupyterlab) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyterlab) (0.2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from requests>=2.28->jupyterlab-server~=2.19->jupyterlab) (2022.12.7)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc~=0.8.0->jupyterlab) (0.19.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipykernel->notebook<7->jupyterlab) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipykernel->notebook<7->jupyterlab) (1.6.7)
# Requirement already satisfied: psutil in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from ipykernel->notebook<7->jupyterlab) (5.9.5)
# Requirement already satisfied: executing>=1.2.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython->jupyterlab) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython->jupyterlab) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython->jupyterlab) (0.2.2)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython->jupyterlab) (1.15.0)
# Requirement already satisfied: fqdn in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (2.3)
# Requirement already satisfied: uri-template in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.4.1)
# Requirement already satisfied: webencodings in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.5.1)
# Requirement already satisfied: pycparser in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /Users/foisys/Library/Python/3.9/lib/python/site-packages (from isoduration->jsonschema>=4.17.3->jupyterlab-server~=2.19->jupyterlab) (1.2.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
