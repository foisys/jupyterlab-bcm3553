# %% [markdown]
# <h1 id="Pr&eacute;paration-de-l'environnement-de-d&eacute;veloppement">Pr&eacute;paration de l'environnement de d&eacute;veloppement</h1>
# <h2 id="Introduction">Introduction</h2>
# <p>Pour r&eacute;soudre notre probl&egrave;me, on a besoin d'un outil: un language de programmation. Ce language doit nous permettre de communiquer avec le mat&eacute;riel de l'ordinateur afin d'ex&eacute;cuter les t&acirc;ches n&eacute;cessaires pour accomplir nos t&acirc;ches: lecture et &eacute;criture sur le syst&egrave;me de fichier, traitement de l'information, connexions avec le monde ext&eacute;rieur si n&eacute;cessaire.</p>
# <h2 id="Nos-outils">Nos outils</h2>
# <p>Comment &nbsp;utiliser un language? La mani&egrave;re la plus simple se fait via un simple fichier en format texte, &eacute;crit via un &eacute;diteur de texte. Simple mais limit&eacute;... Une approche plus payante est l'utilisation d'un environnement de d&eacute;veloppement int&eacute;gr&eacute;. Duh? C'est un logiciel offrant des fonctionnalit&eacute;s compl&eacute;mentaires comme l'indentation automatique ou l'autocorrection. Il existe une multitude de ces outils mais un d'entre eux qui est tr&egrave;s populaire est&nbsp;<a href="http://jupyter.org" target="_blank" rel="noopener">Jupyter</a>. &nbsp;Pourquoi? Parce qu'en plus d'&eacute;crire du code, il est facile de compl&eacute;ter ce code avec de la documentation dans la m&ecirc;me plateforme.</p>
# <h2 id="Installation-locale">Installation locale</h2>
# <p>Donc comment faire avec Jupyter?</p>
# <ol>
# <li>Premi&egrave;rement, il fait avoir Python 3 install&eacute; sur votre ordinateur. Sur une Mac ou sur un poste Linux/Unix, c'est d&eacute;j&agrave; fait ;-) Sur Windows, il faut installer le package provenant du site de Python:&nbsp;<a title="Page des installateurs Windows 7 et plus" href="https://www.python.org/downloads/windows/" target="_blank" rel="noopener">Page des installateurs Windows 7 et plus.</a></li>
# <li>Il est tr&egrave;s facile alors d'insteller Jupyter Lab:</li>
# </ol>
# <p><code>% pip3 install jupyterlab</code><br /><br />On d&eacute;marre alors notre environement ainsi:</p>
# <p><code>% mkdir mon_projet</code><br /><code>% jupyter lab --notebook-dir= ./mon_projet</code></p>
# <p>Une fen&ecirc;tre du fureteur s'ouvrira et on peut commencer!<code></code></p>
# <h2 id="Jupyter-sur-le-Web:-Google-Colab.">Jupyter sur le Web: Google Colab.</h2>
# <p>Si on ne veut pas faire local, on peut passer par le Web :-) Jupyter est le coeur de l'application Google Colab:&nbsp;<a href="https://colab.research.google.com/" target="_blank" rel="noopener">https://colab.research.google.com/.</a></p>
# <p>Premier exercice: cr&eacute;er votre acc&egrave;s &agrave; Colab.</p>
# <h2 id="Aspects-un-peu-plus-avanc&eacute;s">Aspects un peu plus avanc&eacute;s</h2>
# <h3 id="Invoquer-Jupyter-Lab-h&eacute;berg&eacute;-sur-un-autre-ordinateur">Comment acc&eacute;der &agrave; la console du terminal derri&egrave;re le notebook</h3>
# <p>Est-il possible d'envoyer des commandes directement sur le serveur h&eacute;bergeant le service Jupyter? Of course! En utilisant la caract&egrave;re magique "!" dans une fen&ecirc;tre de code:</p>

# %%
# !ls -l ..
# Out:
# total 288
# drwxr-xr-x  1 foisys  staff  16384  9 jan 15:14 0.preparation
# drwxr-xr-x  1 foisys  staff  16384  9 jan 13:26 1.python_variables
# drwxr-xr-x  1 foisys  staff  16384  9 jan 14:35 2.python_looping
# drwxr-xr-x  1 foisys  staff  16384  5 déc 10:35 3.python_fonctions
# drwxr-xr-x  1 foisys  staff  16384  9 jan 15:06 4.python_files
# drwxr-xr-x  1 foisys  staff  16384 17 oct 16:34 5.intro_biopython
# drwxr-xr-x  1 foisys  staff  16384 17 oct 16:48 6.aspects_avances_bioinfo
# drwxr-xr-x  1 foisys  staff  16384  4 jan 15:38 z.exemples_R
# drwxr-xr-x  1 foisys  staff  16384  9 jan 15:09 z.misc_files

# %% [markdown]
# <h3 id="Invoquer-Jupyter-Lab-h&eacute;berg&eacute;-sur-un-autre-ordinateur">Invoquer Jupyter Lab h&eacute;berg&eacute; sur un autre ordinateur</h3>
# <p>Est-il possible d'acc&eacute;der &agrave; une instance de Jupyter Lab qui n'est pas sur votre poste de travail? Sans probl&egrave;me&nbsp;:-)</p>
# <h4 id="1---Sur-le-serveur-distant,-cr&eacute;er-un-mot-de-passe">1 - Sur le serveur distant, cr&eacute;er un mot de passe</h4>
# <h4 id="Ici,-on-assumant-que-Jupyter-Lab-est-install&eacute;-dans-votre-compte-sur-cet-ordinateur-distant,-on-se-connecte-&agrave;-notre-compte-&agrave;-distance.-Pour-simplifier-l'acc&egrave;s-(pas-besoin-d'utiliser-le-jeton-de-connexion),-cr&eacute;ons-un-mot-de-passe-:&nbsp;"><span style="font-weight: 400;">Ici, on assumant que Jupyter Lab est install&eacute; dans votre compte sur cet ordinateur distant, on se connecte &agrave; notre compte &agrave; distance. </span><span style="font-weight: 400;">Pour simplifier l'acc&egrave;s (pas besoin d'utiliser le jeton de connexion), cr&eacute;ons un mot de passe :&nbsp;</span></h4>
# <p style="font-weight: 400;"><span style="font-size: 10pt;"><span style="white-space: pre-wrap; color: #242424; font-family: source-code-pro, Menlo, Monaco, 'Courier New', Courier, monospace; letter-spacing: -0.352px; background-color: #f2f2f2;">% </span><span style="color: #242424; font-family: source-code-pro, Menlo, Monaco, 'Courier New', Courier, monospace; letter-spacing: -0.352px; white-space: pre-wrap; background-color: #f2f2f2;">jupyter lab --generate-config<br /></span></span><span style="font-size: 10pt; white-space: pre-wrap; color: #242424; font-family: source-code-pro, Menlo, Monaco, 'Courier New', Courier, monospace; letter-spacing: -0.352px; background-color: #f2f2f2;">% jupyter lab password</span></p>
# <h4 id="2---Sur-le-serveur-distant,-d&eacute;marrer-Jupyter-Lab-en-mode-redirection">2 - Sur le serveur distant, d&eacute;marrer Jupyter Lab en mode redirection</h4>
# <p>On d&eacute;marre Jupyter Lab en lui sp&eacute;cifiant de ne pas ouvrir de page web locale et d'"&eacute;couter" le traffic sur un port qui sera redirig&eacute;:&nbsp;</p>
# <p><span style="font-size: 10pt;"><span style="white-space: pre-wrap; color: #242424; font-family: source-code-pro, Menlo, Monaco, 'Courier New', Courier, monospace; letter-spacing: -0.352px; background-color: #f2f2f2;">#% jupyter lab --no-browser --port &lt;id_port&gt; --notebook-dir=&lt;my_notebooks&gt;<br /></span><span style="white-space: pre-wrap; color: #242424; font-family: source-code-pro, Menlo, Monaco, 'Courier New', Courier, monospace; letter-spacing: -0.352px; background-color: #f2f2f2;">% jupyter lab --no-browser --port 8889 --notebook-dir=myLocation</span></span></p>
# <h4 id="3---Sur-votre-poste-de-travail,-rediriger-le-traffic-SSH-entre-votre-poste-et-le-serveur-distant">3 - Sur votre poste de travail, rediriger le traffic SSH entre votre poste et le serveur distant</h4>
# <p>En utilisant SSH pour se connecter au serveur distant, il s'agit de rediriger le traffic entre les deux machines en utilisant le port sp&eacute;cifi&eacute; ci-dessus:&nbsp;</p>
# <p><span style="font-size: 10pt;"><span style="white-space: pre-wrap; color: #242424; font-family: source-code-pro, Menlo, Monaco, 'Courier New', Courier, monospace; letter-spacing: -0.352px; background-color: #f2f2f2;">#% </span><span style="color: #242424; font-family: source-code-pro, Menlo, Monaco, 'Courier New', Courier, monospace; letter-spacing: -0.352px; white-space: pre-wrap; background-color: #e8f3e8;">ssh -N -L localhost:&lt;local-port&gt;:localhost:&lt;remote-port&gt; &lt;remote-user&gt;@&lt;remote-host&gt;<br /></span><span style="white-space: pre-wrap; color: #242424; font-family: source-code-pro, Menlo, Monaco, 'Courier New', Courier, monospace; letter-spacing: -0.352px; background-color: #f2f2f2;">% </span><span style="color: #242424; font-family: source-code-pro, Menlo, Monaco, 'Courier New', Courier, monospace; letter-spacing: -0.352px; white-space: pre-wrap; background-color: #e8f3e8;">ssh -N -L localhost:8889:localhost:8889 mon.usager@mon.serveur.distant</span></span></p>
# <h4 id="4---Sur-votre-poste-de-travail,-&nbsp;acc&eacute;der-&agrave;-Jupyter">4 - Sur votre poste de travail, &nbsp;acc&eacute;der &agrave; Jupyter</h4>
# <p>Il suffit maitenant d'ouvrir une page web dans votre fureteur pr&eacute;f&eacute;r&eacute; &agrave; <code>https://localhost:&lt;id_port&gt;</code> et en utilisant le mot de passe ;-)&nbsp;</p>
